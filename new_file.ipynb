# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
vars_df=pd.read_csv('Output/new_clean_data.csv', low_memory=False)

# %%
vars_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 603029 entries, 0 to 603028
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       603029 non-null  int64
#  1   VAERS_ID         603029 non-null  int64
#  2   RECVDATE         603029 non-null  object
#  3   STATE            548870 non-null  object
#  4   AGE_YRS          603029 non-null  int64
#  5   SEX              603029 non-null  object
#  6   DIED             5487 non-null    object
#  7   DATEDIED         5189 non-null    object
#  8   L_THREAT         9042 non-null    object
#  9   HOSPDAYS         22051 non-null   float64
#  10  X_STAY           826 non-null     object
#  11  DISABLE          9041 non-null    object
#  12  RECOVD           548212 non-null  object
#  13  NUMDAYS          566751 non-null  float64
#  14  FORM_VERS        603029 non-null  int64
#  15  ALLERGIES        312592 non-null  object
# ...

# %%
vars_df.loc[vars_df.HOSPDAYS > 100]
# Out:
#         Unnamed: 0  VAERS_ID    RECVDATE STATE  AGE_YRS SEX DIED    DATEDIED  \
# 1572          1572    416969  02/16/2011    AZ       58   M  NaN         NaN
# 3322          3322    422015  05/02/2011    TX       14   F  NaN         NaN
# 10282        10282    437000  10/06/2011    AZ       65   F  NaN         NaN
# 12242        12242    440003  10/25/2011    NY       21   M  NaN         NaN
# 17779        17779    450995  03/02/2012    NJ       49   M  NaN         NaN
# 18669        18669    453304  04/10/2012    CA       23   F  NaN         NaN
# 18923        18923    454037  04/19/2012    CA       29   M  NaN         NaN
# 20564        20564    457632  06/18/2012    CA       53   F  NaN         NaN
# 32882        32882    479593  12/27/2012    FL       50   M  NaN         NaN
# 40853        40853    499020  08/09/2013    TN       18   F  NaN         NaN
# 49270        49270    513844  11/19/2013    IL       25   F  NaN         NaN
# ...
